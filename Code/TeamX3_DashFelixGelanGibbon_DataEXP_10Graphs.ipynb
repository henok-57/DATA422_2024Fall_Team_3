# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

#3 univariate charts that explain your response variable and select independent variables used to answer your research question
data_1 = pd.read_excel('Legs.xlsx')
data_2 = pd.read_excel('Misc.xlsx')
data_3 = pd.read_excel('Slopes.xlsx')

sns.set(rc = {'figure.figsize': (5,5)})
sns.kdeplot(data_1['leg1'], shade = 1)
# Out:
# <ipython-input-8-1dd29f3f22e9>:12: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=1`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data_1['leg1'], shade = 1)
# <Axes: xlabel='leg1', ylabel='Density'>

# %%
fig = plt.figure(figsize =(10, 7))
data_1.drop(columns = ['id'], inplace = True)

axis = fig.add_axes([0, 0, 1, 1])
box_plot = axis.boxplot(data_1)

plt.show()

# %%
sns.stripplot(y = data_2['Body'])
# Out:
# <Axes: ylabel='Body'>

# %%
#3 bivariate charts that explain your response variable and select independent variables used to answer your research question
sns.relplot(x = data_1['leg1'], y = data_1['leg2'], kind = 'line');

# %%
sns.swarmplot(data = data_2, x = "Wick", hue = "Price")
# Out:
# <Axes: xlabel='Wick'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 48.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.lineplot(x = data_3['slope1'], y = data_3['slope4'], color = "green")
# Out:
# <Axes: xlabel='slope1', ylabel='slope4'>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns


#2 high dimensional charts that explain your response variable and select independent variables to answer your research question
#Response variable = dependant variable (outcome you are aiming to predict)
#independent variable = factors that might affect the response variable

#multivariate_scatterplot
multi_data_1 = pd.read_excel('Misc.xlsx')
multi_data_2 = pd.read_excel('Legs.xlsx')
multi_data_3 = pd.read_excel('Slopes.xlsx')

sns.pairplot(data_1[['Price','EMA','Wick','Body']]) #MISC
plt.show()


#2 charts of your choice that you feel describe issues with your data

plt.hist(data_1['Price'],bins = 15, edgecolor='purple')
plt.title('Price Histogram')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

plt.hist(data_1['EMA'],bins = 15, edgecolor='black')
plt.title('EMA Histogram')
plt.xlabel('EMA')
plt.ylabel('Frequency')
plt.show()
